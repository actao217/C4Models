# %%
# !pip install stable-baselines3
# Out:
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Downloading stable_baselines3-2.5.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 53.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 21.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 26.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 55.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable-baselines3-2.5.0

# %%
import numpy as np
from stable_baselines3 import DQN
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.dqn.policies import CnnPolicy, MultiInputPolicy
from stable_baselines3.common.torch_layers import NatureCNN

import gymnasium as gym
from gymnasium import spaces
import numpy as np

# %%
class Connect4Env(gym.Env):
    """Connect4 environment for DQN training."""
    def __init__(self):
        super().__init__()
        self.rows = 6
        self.cols = 7
        self.board = np.zeros((self.rows, self.cols), dtype=np.uint8)  # np.uint8
        self.current_player = 1
        self.action_space = spaces.Discrete(self.cols)
        self.observation_space = spaces.Box(low=0, high=255, shape=(1, self.rows, self.cols), dtype=np.uint8)  # channel-first observation space

    def reset(self, seed=None, options=None):
        """
        Reset the environment to the initial state.
        """
        # initialize board
        self.board = np.zeros((self.rows, self.cols), dtype=np.uint8)
        self.current_player = 1

        # returns channel first array
        return np.expand_dims(self.board, axis=0), {}

    def step(self, action):
        """
        Execute one step in the environment.
        """
        if action not in self.possible_actions():
            return np.expand_dims(self.board, axis=0), -1, True, False, {}

        row = self._drop_piece(action, self.current_player)
        if self._check_win(row, action):
            reward = 1 if self.current_player == 1 else -1
            terminated = True
            truncated = False
        elif np.all(self.board != 0):
            reward = 0
            terminated = True
            truncated = False
        else:
            reward = 0
            terminated = False
            truncated = False

        self.current_player = 2 if self.current_player == 1 else 1
        return np.expand_dims(self.board, axis=0), reward, terminated, truncated, {}

    def _drop_piece(self, col, player):
        """
        Drop a piece in the specified column for the given player.
        """
        for row in reversed(range(self.rows)):
            if self.board[row, col] == 0:
                self.board[row, col] = player
                return row
        return -1

    def _check_win(self, row, col):
        """
        Check if the last move resulted in a win.
        """
        # Check horizontal, vertical, and diagonal wins (leetcode BFS stuff lol)
        directions = [
            (0, 1),  # Horizontal
            (1, 0),  # Vertical
            (1, 1),  # Diagonal (top-left to bottom-right)
            (1, -1),  # Diagonal (top-right to bottom-left)
        ]
        for dr, dc in directions:
            count = 1
            for delta in [-1, 1]:
                r, c = row + delta * dr, col + delta * dc
                while 0 <= r < self.rows and 0 <= c < self.cols and self.board[r, c] == self.board[row, col]:
                    count += 1
                    r += delta * dr
                    c += delta * dc
            if count >= 4:
                return True
        return False

    def possible_actions(self):
        """
        Return a list of valid actions (columns that are not full).
        """
        return [col for col in range(self.cols) if self.board[0, col] == 0]

    def render(self):
        """
        Render the current state of the board.
        """
        print(self.board)
        print()

# %%
import torch.nn as nn
import torch
from stable_baselines3.common.torch_layers import NatureCNN
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

class CustomCNN(BaseFeaturesExtractor):
    """
    Custom CNN architecture for Connect 4.
    """
    def __init__(self, observation_space, features_dim=512, normalized_image=False):
        super().__init__(observation_space, features_dim)
        # CNN layers
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1), # made kernel size smaller
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Flatten(),
        )

        # output dimension of the CNN
        with torch.no_grad():
            sample_input = torch.as_tensor(observation_space.sample()[None]).float()
            n_flatten = self.cnn(sample_input).shape[1]

        # define the fully connected layer
        self.linear = nn.Sequential(
            nn.Linear(n_flatten, features_dim),
            nn.ReLU(),
        )

    def forward(self, observations):
        # forward pass through the CNN
        return self.linear(self.cnn(observations))

# train and save DQN with a specific policy
def train_and_save_dqn(policy, policy_name, total_timesteps=100_000):
    print(f"Training DQN with {policy_name} policy...")

    env = Connect4Env()
    env = DummyVecEnv([lambda: env])

    # DQN model with the CNN architecture
    model = DQN(
        policy,
        env,
        verbose=1,
        tensorboard_log=f"./dqn_{policy_name}_tensorboard/",
        policy_kwargs=dict(
            features_extractor_class=CustomCNN,
            features_extractor_kwargs=dict(normalized_image=False)
        )
    )

    model.learn(total_timesteps=total_timesteps)
    model.save(f"dqn_{policy_name}_connect4_model")
    print(f"Training complete. Model saved as dqn_{policy_name}_connect4_model.")

# train and save DQN with CNN Policy
train_and_save_dqn(CnnPolicy, "cnn", total_timesteps=100_000)
# Out:
# Streaming output truncated to the last 5000 lines.
# |    time_elapsed     | 1149     |
# |    total_timesteps  | 64142    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00548  |
# |    n_updates        | 16010    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6240     |
# |    fps              | 55       |
# |    time_elapsed     | 1151     |
# |    total_timesteps  | 64230    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00726  |
# |    n_updates        | 16032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6244     |
# |    fps              | 55       |
# |    time_elapsed     | 1153     |
# |    total_timesteps  | 64330    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00126  |
# |    n_updates        | 16057    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6248     |
# |    fps              | 55       |
# |    time_elapsed     | 1155     |
# |    total_timesteps  | 64435    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00139  |
# |    n_updates        | 16083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6252     |
# |    fps              | 55       |
# |    time_elapsed     | 1157     |
# |    total_timesteps  | 64542    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 16110    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6256     |
# |    fps              | 55       |
# |    time_elapsed     | 1159     |
# |    total_timesteps  | 64649    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00217  |
# |    n_updates        | 16137    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6260     |
# |    fps              | 55       |
# |    time_elapsed     | 1160     |
# |    total_timesteps  | 64738    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00322  |
# |    n_updates        | 16159    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6264     |
# |    fps              | 55       |
# |    time_elapsed     | 1162     |
# |    total_timesteps  | 64824    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00213  |
# |    n_updates        | 16180    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6268     |
# |    fps              | 55       |
# |    time_elapsed     | 1163     |
# |    total_timesteps  | 64923    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00543  |
# |    n_updates        | 16205    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6272     |
# |    fps              | 55       |
# |    time_elapsed     | 1166     |
# |    total_timesteps  | 65018    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00146  |
# |    n_updates        | 16229    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6276     |
# |    fps              | 55       |
# |    time_elapsed     | 1167     |
# |    total_timesteps  | 65111    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00152  |
# |    n_updates        | 16252    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6280     |
# |    fps              | 55       |
# |    time_elapsed     | 1169     |
# |    total_timesteps  | 65216    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00636  |
# |    n_updates        | 16278    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6284     |
# |    fps              | 55       |
# |    time_elapsed     | 1171     |
# |    total_timesteps  | 65307    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00613  |
# |    n_updates        | 16301    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6288     |
# |    fps              | 55       |
# |    time_elapsed     | 1172     |
# |    total_timesteps  | 65407    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0352   |
# |    n_updates        | 16326    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6292     |
# |    fps              | 55       |
# |    time_elapsed     | 1174     |
# |    total_timesteps  | 65508    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00114  |
# |    n_updates        | 16351    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6296     |
# |    fps              | 55       |
# |    time_elapsed     | 1175     |
# |    total_timesteps  | 65591    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0309   |
# |    n_updates        | 16372    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6300     |
# |    fps              | 55       |
# |    time_elapsed     | 1178     |
# |    total_timesteps  | 65683    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00137  |
# |    n_updates        | 16395    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6304     |
# |    fps              | 55       |
# |    time_elapsed     | 1180     |
# |    total_timesteps  | 65788    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 16421    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6308     |
# |    fps              | 55       |
# |    time_elapsed     | 1181     |
# |    total_timesteps  | 65871    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00761  |
# |    n_updates        | 16442    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6312     |
# |    fps              | 55       |
# |    time_elapsed     | 1182     |
# |    total_timesteps  | 65946    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00471  |
# |    n_updates        | 16461    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6316     |
# |    fps              | 55       |
# |    time_elapsed     | 1184     |
# |    total_timesteps  | 66032    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0269   |
# |    n_updates        | 16482    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6320     |
# |    fps              | 55       |
# |    time_elapsed     | 1185     |
# |    total_timesteps  | 66095    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00919  |
# |    n_updates        | 16498    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6324     |
# |    fps              | 55       |
# |    time_elapsed     | 1186     |
# |    total_timesteps  | 66182    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 16520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6328     |
# |    fps              | 55       |
# |    time_elapsed     | 1188     |
# |    total_timesteps  | 66278    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000693 |
# |    n_updates        | 16544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6332     |
# |    fps              | 55       |
# |    time_elapsed     | 1190     |
# |    total_timesteps  | 66376    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00172  |
# |    n_updates        | 16568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6336     |
# |    fps              | 55       |
# |    time_elapsed     | 1192     |
# |    total_timesteps  | 66484    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00163  |
# |    n_updates        | 16595    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6340     |
# |    fps              | 55       |
# |    time_elapsed     | 1195     |
# |    total_timesteps  | 66607    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 16626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6344     |
# |    fps              | 55       |
# |    time_elapsed     | 1196     |
# |    total_timesteps  | 66700    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00911  |
# |    n_updates        | 16649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6348     |
# |    fps              | 55       |
# |    time_elapsed     | 1198     |
# |    total_timesteps  | 66803    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00957  |
# |    n_updates        | 16675    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6352     |
# |    fps              | 55       |
# |    time_elapsed     | 1200     |
# |    total_timesteps  | 66901    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00948  |
# |    n_updates        | 16700    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6356     |
# |    fps              | 55       |
# |    time_elapsed     | 1201     |
# |    total_timesteps  | 66993    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 16723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6360     |
# |    fps              | 55       |
# |    time_elapsed     | 1204     |
# |    total_timesteps  | 67089    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0233   |
# |    n_updates        | 16747    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6364     |
# |    fps              | 55       |
# |    time_elapsed     | 1205     |
# |    total_timesteps  | 67183    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 16770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6368     |
# |    fps              | 55       |
# |    time_elapsed     | 1207     |
# |    total_timesteps  | 67286    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00022  |
# |    n_updates        | 16796    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6372     |
# |    fps              | 55       |
# |    time_elapsed     | 1209     |
# |    total_timesteps  | 67377    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0038   |
# |    n_updates        | 16819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6376     |
# |    fps              | 55       |
# |    time_elapsed     | 1210     |
# |    total_timesteps  | 67444    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000217 |
# |    n_updates        | 16835    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6380     |
# |    fps              | 55       |
# |    time_elapsed     | 1211     |
# |    total_timesteps  | 67532    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000968 |
# |    n_updates        | 16857    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6384     |
# |    fps              | 55       |
# |    time_elapsed     | 1213     |
# |    total_timesteps  | 67627    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00166  |
# |    n_updates        | 16881    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6388     |
# |    fps              | 55       |
# |    time_elapsed     | 1215     |
# |    total_timesteps  | 67728    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00663  |
# |    n_updates        | 16906    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6392     |
# |    fps              | 55       |
# |    time_elapsed     | 1217     |
# |    total_timesteps  | 67822    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.003    |
# |    n_updates        | 16930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6396     |
# |    fps              | 55       |
# |    time_elapsed     | 1218     |
# |    total_timesteps  | 67903    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00273  |
# |    n_updates        | 16950    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6400     |
# |    fps              | 55       |
# |    time_elapsed     | 1220     |
# |    total_timesteps  | 67980    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00464  |
# |    n_updates        | 16969    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6404     |
# |    fps              | 55       |
# |    time_elapsed     | 1221     |
# |    total_timesteps  | 68074    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00392  |
# |    n_updates        | 16993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6408     |
# |    fps              | 55       |
# |    time_elapsed     | 1223     |
# |    total_timesteps  | 68155    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0012   |
# |    n_updates        | 17013    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6412     |
# |    fps              | 55       |
# |    time_elapsed     | 1224     |
# |    total_timesteps  | 68250    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00291  |
# |    n_updates        | 17037    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6416     |
# |    fps              | 55       |
# |    time_elapsed     | 1226     |
# |    total_timesteps  | 68354    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00125  |
# |    n_updates        | 17063    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6420     |
# |    fps              | 55       |
# |    time_elapsed     | 1228     |
# |    total_timesteps  | 68448    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0035   |
# |    n_updates        | 17086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6424     |
# |    fps              | 55       |
# |    time_elapsed     | 1230     |
# |    total_timesteps  | 68556    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 17113    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6428     |
# |    fps              | 55       |
# |    time_elapsed     | 1232     |
# |    total_timesteps  | 68649    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00264  |
# |    n_updates        | 17137    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6432     |
# |    fps              | 55       |
# |    time_elapsed     | 1233     |
# |    total_timesteps  | 68728    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00583  |
# |    n_updates        | 17156    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6436     |
# |    fps              | 55       |
# |    time_elapsed     | 1235     |
# |    total_timesteps  | 68810    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00624  |
# |    n_updates        | 17177    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6440     |
# |    fps              | 55       |
# |    time_elapsed     | 1236     |
# |    total_timesteps  | 68897    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00131  |
# |    n_updates        | 17199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6444     |
# |    fps              | 55       |
# |    time_elapsed     | 1238     |
# |    total_timesteps  | 68996    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00593  |
# |    n_updates        | 17223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6448     |
# |    fps              | 55       |
# |    time_elapsed     | 1240     |
# |    total_timesteps  | 69089    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00275  |
# |    n_updates        | 17247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6452     |
# |    fps              | 55       |
# |    time_elapsed     | 1242     |
# |    total_timesteps  | 69180    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000923 |
# |    n_updates        | 17269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6456     |
# |    fps              | 55       |
# |    time_elapsed     | 1243     |
# |    total_timesteps  | 69270    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00452  |
# |    n_updates        | 17292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6460     |
# |    fps              | 55       |
# |    time_elapsed     | 1245     |
# |    total_timesteps  | 69358    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00232  |
# |    n_updates        | 17314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6464     |
# |    fps              | 55       |
# |    time_elapsed     | 1247     |
# |    total_timesteps  | 69461    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00216  |
# |    n_updates        | 17340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6468     |
# |    fps              | 55       |
# |    time_elapsed     | 1248     |
# |    total_timesteps  | 69556    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00535  |
# |    n_updates        | 17363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6472     |
# |    fps              | 55       |
# |    time_elapsed     | 1250     |
# |    total_timesteps  | 69646    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00352  |
# |    n_updates        | 17386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6476     |
# |    fps              | 55       |
# |    time_elapsed     | 1252     |
# |    total_timesteps  | 69742    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00613  |
# |    n_updates        | 17410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6480     |
# |    fps              | 55       |
# |    time_elapsed     | 1254     |
# |    total_timesteps  | 69825    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000532 |
# |    n_updates        | 17431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6484     |
# |    fps              | 55       |
# |    time_elapsed     | 1255     |
# |    total_timesteps  | 69909    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00148  |
# |    n_updates        | 17452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6488     |
# |    fps              | 55       |
# |    time_elapsed     | 1257     |
# |    total_timesteps  | 69987    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00377  |
# |    n_updates        | 17471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6492     |
# |    fps              | 55       |
# |    time_elapsed     | 1258     |
# |    total_timesteps  | 70070    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00431  |
# |    n_updates        | 17492    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6496     |
# |    fps              | 55       |
# |    time_elapsed     | 1260     |
# |    total_timesteps  | 70164    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00406  |
# |    n_updates        | 17515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6500     |
# |    fps              | 55       |
# |    time_elapsed     | 1261     |
# |    total_timesteps  | 70248    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00117  |
# |    n_updates        | 17536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6504     |
# |    fps              | 55       |
# |    time_elapsed     | 1263     |
# |    total_timesteps  | 70342    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00639  |
# |    n_updates        | 17560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6508     |
# |    fps              | 55       |
# |    time_elapsed     | 1265     |
# |    total_timesteps  | 70453    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00124  |
# |    n_updates        | 17588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6512     |
# |    fps              | 55       |
# |    time_elapsed     | 1267     |
# |    total_timesteps  | 70560    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00729  |
# |    n_updates        | 17614    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6516     |
# |    fps              | 55       |
# |    time_elapsed     | 1269     |
# |    total_timesteps  | 70647    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00443  |
# |    n_updates        | 17636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6520     |
# |    fps              | 55       |
# |    time_elapsed     | 1270     |
# |    total_timesteps  | 70734    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 17658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6524     |
# |    fps              | 55       |
# |    time_elapsed     | 1272     |
# |    total_timesteps  | 70838    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00143  |
# |    n_updates        | 17684    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6528     |
# |    fps              | 55       |
# |    time_elapsed     | 1273     |
# |    total_timesteps  | 70918    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00448  |
# |    n_updates        | 17704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6532     |
# |    fps              | 55       |
# |    time_elapsed     | 1275     |
# |    total_timesteps  | 71015    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 17728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6536     |
# |    fps              | 55       |
# |    time_elapsed     | 1277     |
# |    total_timesteps  | 71110    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 17752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6540     |
# |    fps              | 55       |
# |    time_elapsed     | 1278     |
# |    total_timesteps  | 71190    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00342  |
# |    n_updates        | 17772    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6544     |
# |    fps              | 55       |
# |    time_elapsed     | 1280     |
# |    total_timesteps  | 71268    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00213  |
# |    n_updates        | 17791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6548     |
# |    fps              | 55       |
# |    time_elapsed     | 1281     |
# |    total_timesteps  | 71346    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00367  |
# |    n_updates        | 17811    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6552     |
# |    fps              | 55       |
# |    time_elapsed     | 1283     |
# |    total_timesteps  | 71446    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00862  |
# |    n_updates        | 17836    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6556     |
# |    fps              | 55       |
# |    time_elapsed     | 1285     |
# |    total_timesteps  | 71554    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0027   |
# |    n_updates        | 17863    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6560     |
# |    fps              | 55       |
# |    time_elapsed     | 1286     |
# |    total_timesteps  | 71640    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00712  |
# |    n_updates        | 17884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6564     |
# |    fps              | 55       |
# |    time_elapsed     | 1288     |
# |    total_timesteps  | 71716    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00211  |
# |    n_updates        | 17903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6568     |
# |    fps              | 55       |
# |    time_elapsed     | 1289     |
# |    total_timesteps  | 71795    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00207  |
# |    n_updates        | 17923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6572     |
# |    fps              | 55       |
# |    time_elapsed     | 1291     |
# |    total_timesteps  | 71867    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00545  |
# |    n_updates        | 17941    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6576     |
# |    fps              | 55       |
# |    time_elapsed     | 1293     |
# |    total_timesteps  | 71959    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00347  |
# |    n_updates        | 17964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6580     |
# |    fps              | 55       |
# |    time_elapsed     | 1294     |
# |    total_timesteps  | 72049    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00328  |
# |    n_updates        | 17987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6584     |
# |    fps              | 55       |
# |    time_elapsed     | 1296     |
# |    total_timesteps  | 72143    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00602  |
# |    n_updates        | 18010    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6588     |
# |    fps              | 55       |
# |    time_elapsed     | 1297     |
# |    total_timesteps  | 72217    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00251  |
# |    n_updates        | 18029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6592     |
# |    fps              | 55       |
# |    time_elapsed     | 1298     |
# |    total_timesteps  | 72293    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00697  |
# |    n_updates        | 18048    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6596     |
# |    fps              | 55       |
# |    time_elapsed     | 1300     |
# |    total_timesteps  | 72387    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00204  |
# |    n_updates        | 18071    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6600     |
# |    fps              | 55       |
# |    time_elapsed     | 1302     |
# |    total_timesteps  | 72477    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00403  |
# |    n_updates        | 18094    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6604     |
# |    fps              | 55       |
# |    time_elapsed     | 1304     |
# |    total_timesteps  | 72565    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00415  |
# |    n_updates        | 18116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6608     |
# |    fps              | 55       |
# |    time_elapsed     | 1305     |
# |    total_timesteps  | 72650    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0025   |
# |    n_updates        | 18137    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6612     |
# |    fps              | 55       |
# |    time_elapsed     | 1307     |
# |    total_timesteps  | 72733    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0024   |
# |    n_updates        | 18158    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6616     |
# |    fps              | 55       |
# |    time_elapsed     | 1308     |
# |    total_timesteps  | 72797    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00197  |
# |    n_updates        | 18174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6620     |
# |    fps              | 55       |
# |    time_elapsed     | 1309     |
# |    total_timesteps  | 72879    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000522 |
# |    n_updates        | 18194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6624     |
# |    fps              | 55       |
# |    time_elapsed     | 1311     |
# |    total_timesteps  | 72964    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00468  |
# |    n_updates        | 18215    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6628     |
# |    fps              | 55       |
# |    time_elapsed     | 1312     |
# |    total_timesteps  | 73058    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00861  |
# |    n_updates        | 18239    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6632     |
# |    fps              | 55       |
# |    time_elapsed     | 1314     |
# |    total_timesteps  | 73147    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00973  |
# |    n_updates        | 18261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6636     |
# |    fps              | 55       |
# |    time_elapsed     | 1315     |
# |    total_timesteps  | 73221    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00889  |
# |    n_updates        | 18280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6640     |
# |    fps              | 55       |
# |    time_elapsed     | 1317     |
# |    total_timesteps  | 73310    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00142  |
# |    n_updates        | 18302    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6644     |
# |    fps              | 55       |
# |    time_elapsed     | 1319     |
# |    total_timesteps  | 73394    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 18323    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6648     |
# |    fps              | 55       |
# |    time_elapsed     | 1320     |
# |    total_timesteps  | 73478    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00287  |
# |    n_updates        | 18344    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6652     |
# |    fps              | 55       |
# |    time_elapsed     | 1322     |
# |    total_timesteps  | 73562    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0462   |
# |    n_updates        | 18365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6656     |
# |    fps              | 55       |
# |    time_elapsed     | 1323     |
# |    total_timesteps  | 73619    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# ...
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7636     |
# |    fps              | 55       |
# |    time_elapsed     | 1748     |
# |    total_timesteps  | 96708    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 24151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7640     |
# |    fps              | 55       |
# |    time_elapsed     | 1750     |
# |    total_timesteps  | 96814    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0041   |
# |    n_updates        | 24178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7644     |
# |    fps              | 55       |
# |    time_elapsed     | 1752     |
# |    total_timesteps  | 96917    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0042   |
# |    n_updates        | 24204    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7648     |
# |    fps              | 55       |
# |    time_elapsed     | 1754     |
# |    total_timesteps  | 97006    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00207  |
# |    n_updates        | 24226    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7652     |
# |    fps              | 55       |
# |    time_elapsed     | 1755     |
# |    total_timesteps  | 97087    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0283   |
# |    n_updates        | 24246    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7656     |
# |    fps              | 55       |
# |    time_elapsed     | 1757     |
# |    total_timesteps  | 97182    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00377  |
# |    n_updates        | 24270    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7660     |
# |    fps              | 55       |
# |    time_elapsed     | 1758     |
# |    total_timesteps  | 97278    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0335   |
# |    n_updates        | 24294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7664     |
# |    fps              | 55       |
# |    time_elapsed     | 1760     |
# |    total_timesteps  | 97356    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 24313    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7668     |
# |    fps              | 55       |
# |    time_elapsed     | 1762     |
# |    total_timesteps  | 97458    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00899  |
# |    n_updates        | 24339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7672     |
# |    fps              | 55       |
# |    time_elapsed     | 1764     |
# |    total_timesteps  | 97565    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 24366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7676     |
# |    fps              | 55       |
# |    time_elapsed     | 1765     |
# |    total_timesteps  | 97642    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00485  |
# |    n_updates        | 24385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7680     |
# |    fps              | 55       |
# |    time_elapsed     | 1767     |
# |    total_timesteps  | 97756    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 24413    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7684     |
# |    fps              | 55       |
# |    time_elapsed     | 1769     |
# |    total_timesteps  | 97827    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00218  |
# |    n_updates        | 24431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7688     |
# |    fps              | 55       |
# |    time_elapsed     | 1770     |
# |    total_timesteps  | 97912    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 24452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7692     |
# |    fps              | 55       |
# |    time_elapsed     | 1772     |
# |    total_timesteps  | 98013    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.036    |
# |    n_updates        | 24478    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7696     |
# |    fps              | 55       |
# |    time_elapsed     | 1775     |
# |    total_timesteps  | 98142    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0015   |
# |    n_updates        | 24510    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7700     |
# |    fps              | 55       |
# |    time_elapsed     | 1776     |
# |    total_timesteps  | 98212    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0277   |
# |    n_updates        | 24527    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7704     |
# |    fps              | 55       |
# |    time_elapsed     | 1777     |
# |    total_timesteps  | 98293    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000573 |
# |    n_updates        | 24548    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7708     |
# |    fps              | 55       |
# |    time_elapsed     | 1779     |
# |    total_timesteps  | 98375    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000773 |
# |    n_updates        | 24568    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7712     |
# |    fps              | 55       |
# |    time_elapsed     | 1781     |
# |    total_timesteps  | 98479    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00402  |
# |    n_updates        | 24594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7716     |
# |    fps              | 55       |
# |    time_elapsed     | 1782     |
# |    total_timesteps  | 98586    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00131  |
# |    n_updates        | 24621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7720     |
# |    fps              | 55       |
# |    time_elapsed     | 1785     |
# |    total_timesteps  | 98689    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0011   |
# |    n_updates        | 24647    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7724     |
# |    fps              | 55       |
# |    time_elapsed     | 1787     |
# |    total_timesteps  | 98796    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000803 |
# |    n_updates        | 24673    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7728     |
# |    fps              | 55       |
# |    time_elapsed     | 1788     |
# |    total_timesteps  | 98884    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0069   |
# |    n_updates        | 24695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7732     |
# |    fps              | 55       |
# |    time_elapsed     | 1790     |
# |    total_timesteps  | 98978    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 24719    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7736     |
# |    fps              | 55       |
# |    time_elapsed     | 1792     |
# |    total_timesteps  | 99075    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0567   |
# |    n_updates        | 24743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7740     |
# |    fps              | 55       |
# |    time_elapsed     | 1793     |
# |    total_timesteps  | 99184    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000836 |
# |    n_updates        | 24770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7744     |
# |    fps              | 55       |
# |    time_elapsed     | 1795     |
# |    total_timesteps  | 99265    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 24791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7748     |
# |    fps              | 55       |
# |    time_elapsed     | 1797     |
# |    total_timesteps  | 99349    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0764   |
# |    n_updates        | 24812    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7752     |
# |    fps              | 55       |
# |    time_elapsed     | 1799     |
# |    total_timesteps  | 99460    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000393 |
# |    n_updates        | 24839    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7756     |
# |    fps              | 55       |
# |    time_elapsed     | 1801     |
# |    total_timesteps  | 99575    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000776 |
# |    n_updates        | 24868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7760     |
# |    fps              | 55       |
# |    time_elapsed     | 1803     |
# |    total_timesteps  | 99668    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00294  |
# |    n_updates        | 24891    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7764     |
# |    fps              | 55       |
# |    time_elapsed     | 1804     |
# |    total_timesteps  | 99759    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000913 |
# |    n_updates        | 24914    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7768     |
# |    fps              | 55       |
# |    time_elapsed     | 1806     |
# |    total_timesteps  | 99839    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0299   |
# |    n_updates        | 24934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7772     |
# |    fps              | 55       |
# |    time_elapsed     | 1807     |
# |    total_timesteps  | 99944    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0352   |
# |    n_updates        | 24960    |
# ----------------------------------
# Training complete. Model saved as dqn_cnn_connect4_model.
